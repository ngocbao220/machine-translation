# %% [markdown]
# # Sử dụng mô hình Transformer để giải quyết bài toán dịch máy
#
# ## Giới thiệu về transformer
#
# TODO
#
# ## Kiến trúc mô hình
#
# TODO

# %% [markdown]
# ## Dependency

# %%
# NLP
import sentencepiece as spm

# DL
import torch
import torch.nn as nn
import torch.optim as optim

# Helper
import tqdm

# %% [markdown]
# ## Config

# %%
TRAIN_EN_PATH = "../data/IWSLT15/train.en.txt"
TRAIN_VI_PATH = "../data/IWSLT15/train.vi.txt"

TEST_EN_12_PATH = "../data/IWSLT15/tst2012.en.txt"
TEST_VI_12_PATH = "../data/IWSLT15/tst2012.vi.txt"

TEST_VI_13_PATH = "../data/IWSLT15/tst2013.vi.txt"
TEST_VI_13_PATH = "../data/IWSLT15/tst2013.vi.txt"

# %% [markdown]
# ## Chuẩn bị dữ liệu

# %%
spm.SentencePieceTrainer.Train(
    input=TRAIN_VI_PATH, model_prefix='spm_vi', vocab_size=10000, model_type='bpe', character_coverage=1.0
)

spm.SentencePieceTrainer.Train(
    input=TRAIN_EN_PATH, model_prefix='spm_en', vocab_size=10000, model_type='bpe', character_coverage=1.0
)

# %% [markdown]
# ## Cài đặt mô hình
