# %%
# !nvidia-smi
# Out:
# Wed Dec 17 05:19:29 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 570.172.08             Driver Version: 570.172.08     CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   52C    P0             27W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !rm -r /kaggle/working/machine-translation

# %%
# %cd /kaggle/working
# !git clone https://github.com/ngocbao220/machine-translation.git
# Out:
# /kaggle/working
# Cloning into 'machine-translation'...
# remote: Enumerating objects: 310, done.
# remote: Counting objects: 100% (166/166), done.
# remote: Compressing objects: 100% (99/99), done.
# remote: Total 310 (delta 72), reused 135 (delta 48), pack-reused 144 (from 1)
# Receiving objects: 100% (310/310), 83.74 MiB | 24.12 MiB/s, done.
# Resolving deltas: 100% (109/109), done.
# Updating files: 100% (124/124), done.

# %%
# %cd machine-translation
# %pip install -r requirements.txt
# Out:
# /kaggle/working/machine-translation
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python3 src/helper/train.py --use_wandb --batch_size 64 --epochs 30 --lr 0.0005 --wandb_api_key "4379f72f74531ca44486a34cb4e859dc0e3cf103"
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# ...
