# %%
# !nvidia-smi
# Out:
# Tue Dec 16 18:20:54 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 570.172.08             Driver Version: 570.172.08     CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   70C    P0             42W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   67C    P0             41W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !rm -r /kaggle/working/machine-translation

# %%
# %cd /kaggle/working
# !git clone https://github.com/ngocbao220/machine-translation.git
# Out:
# /kaggle/working
# Cloning into 'machine-translation'...
# remote: Enumerating objects: 179, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 179 (delta 17), reused 29 (delta 14), pack-reused 144 (from 1)
# Receiving objects: 100% (179/179), 83.67 MiB | 23.54 MiB/s, done.
# Resolving deltas: 100% (54/54), done.
# Updating files: 100% (84/84), done.

# %%
# %cd machine-translation
print("🚀 Bắt đầu huấn luyện mô hình Dịch máy...")
print("Src: en | Tgt: vi")
print("---------------------------------------------")

import subprocess; subprocess.run([
    "python", "src/helper/train.py",
    "--data_dir", "./data/processed/ALT",
    "--base_checkpoint_dir", "./checkpoints",
    "--model_name", "transformer_base",
    "--dataset_name", "ALT",
    "--src_lang", "en",
    "--tgt_lang", "vi",
    "--batch_size", "64",
    "--lr", "0.0001",
    "--epochs", "20",
    "--vocab_size", "10000",
    "--bos_idx", "2",
    "--eos_idx", "3",
    "--add_timestamp",
], check=True)

print("✅ Quá trình huấn luyện kết thúc!")
# Out:
# /kaggle/working/machine-translation
# 🚀 Bắt đầu huấn luyện mô hình Dịch máy...
# Src: en | Tgt: vi
# ---------------------------------------------
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# Checkpoints will be saved to: ./checkpoints/transformer_base/ALT/en_vi/20251216_182108
# 🚀 Starting training with config: {'data_dir': './data/processed/ALT', 'base_checkpoint_dir': './checkpoints', 'model_name': 'transformer_base', 'dataset_name': 'ALT', 'src_lang': 'en', 'tgt_lang': 'vi', 'add_timestamp': True, 'batch_size': 64, 'lr': 0.0001, 'epochs': 20, 'no_gpu': False, 'use_wandb': False, 'vocab_size': 10000, 'bos_idx': 2, 'eos_idx': 3, 'gpu_mode': True, 'save_dir': './checkpoints/transformer_base/ALT/en_vi/20251216_182108'}
# Running on: cuda
# Found Source: ./data/processed/ALT/data_en.txt
# Found Target: ./data/processed/ALT/data_vi.txt
# Loading existing tokenizer from ./data/processed/ALT/bpe_model.json...
# Vocab Size: 10000
# ⚠️ Actual Tokenizer Vocab Size: 10000 (Config requested: 10000)
# 🚀 Using 2 GPUs!
# Train Epoch 1:   0%|          | 0/10 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/functional.py:5962: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
# Train Epoch 1: 100%|██████████| 10/10 [00:02<00:00,  4.68it/s, loss=8.09]
# Val Epoch 1: 100%|██████████| 2/2 [00:00<00:00,  6.62it/s]
# Example Val Pred: 44444444444444
# Example Val Real: 9Inyq;*nY
# Epoch 1 | Train Loss: 8.7136 | Val Loss: 8.2367 | BLEU: 0.00
# 🌟 Saved new best model with loss: 8.2367
# Train Epoch 2: 100%|██████████| 10/10 [00:01<00:00,  8.03it/s, loss=7.29]
# Val Epoch 2: 100%|██████████| 2/2 [00:00<00:00,  8.07it/s]
# Example Val Pred: 44444444444444
# Example Val Real: 9Inyq;*nY
# Epoch 2 | Train Loss: 7.7982 | Val Loss: 7.6954 | BLEU: 0.00
# 🌟 Saved new best model with loss: 7.6954
# Train Epoch 3: 100%|██████████| 10/10 [00:01<00:00,  8.01it/s, loss=6.71]
# Val Epoch 3: 100%|██████████| 2/2 [00:00<00:00,  8.14it/s]
# Example Val Pred: 11111111111111
# Example Val Real: 9Inyq;*nY
# Epoch 3 | Train Loss: 7.1697 | Val Loss: 7.2064 | BLEU: 0.00
# 🌟 Saved new best model with loss: 7.2064
# Train Epoch 4: 100%|██████████| 10/10 [00:01<00:00,  7.97it/s, loss=6.13]
# Val Epoch 4: 100%|██████████| 2/2 [00:00<00:00,  7.76it/s]
# Example Val Pred: 44444444444444
# Example Val Real: 9Inyq;*nY
# Epoch 4 | Train Loss: 6.5822 | Val Loss: 6.7842 | BLEU: 0.00
# 🌟 Saved new best model with loss: 6.7842
# Train Epoch 5: 100%|██████████| 10/10 [00:01<00:00,  7.80it/s, loss=5.58]
# Val Epoch 5: 100%|██████████| 2/2 [00:00<00:00,  7.62it/s]
# Example Val Pred: 44444444444444
# Example Val Real: 9Inyq;*nY
# Epoch 5 | Train Loss: 5.9989 | Val Loss: 6.5677 | BLEU: 0.00
# 🌟 Saved new best model with loss: 6.5677
# Train Epoch 6: 100%|██████████| 10/10 [00:01<00:00,  7.71it/s, loss=5.2]
# Val Epoch 6: 100%|██████████| 2/2 [00:00<00:00,  7.72it/s]
# Example Val Pred: FFFFkFkFkFkFkF
# Example Val Real: 9Inyq;*nY
# Epoch 6 | Train Loss: 5.5351 | Val Loss: 6.5102 | BLEU: 0.00
# 🌟 Saved new best model with loss: 6.5102
# Train Epoch 7: 100%|██████████| 10/10 [00:01<00:00,  7.95it/s, loss=4.75]
# Val Epoch 7: 100%|██████████| 2/2 [00:00<00:00,  7.48it/s]
# Example Val Pred: FFFFFFFFFFFFFF
# Example Val Real: 9Inyq;*nY
# Epoch 7 | Train Loss: 5.1309 | Val Loss: 6.6041 | BLEU: 0.00
# Train Epoch 8: 100%|██████████| 10/10 [00:01<00:00,  7.82it/s, loss=4.62]
# Val Epoch 8: 100%|██████████| 2/2 [00:00<00:00,  7.69it/s]
# Example Val Pred: FFFFFFFFFFFFFF
# Example Val Real: 9Inyq;*nY
# Epoch 8 | Train Loss: 4.8443 | Val Loss: 6.2888 | BLEU: 0.00
# 🌟 Saved new best model with loss: 6.2888
# Train Epoch 9: 100%|██████████| 10/10 [00:01<00:00,  7.98it/s, loss=4.39]
# Val Epoch 9: 100%|██████████| 2/2 [00:00<00:00,  7.78it/s]
# Example Val Pred: 44F444F4F4F444
# Example Val Real: 9Inyq;*nY
# Epoch 9 | Train Loss: 4.6741 | Val Loss: 6.3238 | BLEU: 0.00
# Train Epoch 10: 100%|██████████| 10/10 [00:01<00:00,  8.08it/s, loss=4.18]
# Val Epoch 10: 100%|██████████| 2/2 [00:00<00:00,  6.99it/s]
# Example Val Pred: 44444444444444
# Example Val Real: 9Inyq;*nY
# Epoch 10 | Train Loss: 4.4273 | Val Loss: 6.2679 | BLEU: 0.00
# 🌟 Saved new best model with loss: 6.2679
# Train Epoch 11: 100%|██████████| 10/10 [00:01<00:00,  7.96it/s, loss=4.03]
# Val Epoch 11: 100%|██████████| 2/2 [00:00<00:00,  7.56it/s]
# Example Val Pred: FFFFFFFFFFFFFF
# Example Val Real: 9Inyq;*nY
# Epoch 11 | Train Loss: 4.2606 | Val Loss: 6.1977 | BLEU: 0.00
# 🌟 Saved new best model with loss: 6.1977
# Train Epoch 12: 100%|██████████| 10/10 [00:01<00:00,  8.11it/s, loss=3.97]
# Val Epoch 12: 100%|██████████| 2/2 [00:00<00:00,  7.76it/s]
# Example Val Pred: AAAAAAwwwwwwww
# Example Val Real: 9Inyq;*nY
# Epoch 12 | Train Loss: 4.1661 | Val Loss: 6.2546 | BLEU: 0.00
# Train Epoch 13: 100%|██████████| 10/10 [00:01<00:00,  7.87it/s, loss=3.8]
# Val Epoch 13: 100%|██████████| 2/2 [00:00<00:00,  7.36it/s]
# Example Val Pred: fffffffffffxfF
# Example Val Real: 9Inyq;*nY
# Epoch 13 | Train Loss: 3.9570 | Val Loss: 6.1723 | BLEU: 0.00
# Traceback (most recent call last):
#   File "/kaggle/working/machine-translation/src/helper/train.py", line 348, in <module>
#     run_training(config)
#   File "/kaggle/working/machine-translation/src/helper/train.py", line 321, in run_training
#     trainer.save_checkpoint(epoch, val_loss, is_best)
#   File "/kaggle/working/machine-translation/src/helper/train.py", line 185, in save_checkpoint
#     torch.save(state, filename)
#   File "/usr/local/lib/python3.11/dist-packages/torch/serialization.py", line 944, in save
#     _save(
#   File "/usr/local/lib/python3.11/dist-packages/torch/serialization.py", line 1214, in _save
#     storage = storage.cpu()
#               ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/storage.py", line 267, in cpu
#     return torch.UntypedStorage(self.size()).copy_(self, False)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_91/2859989431.py in <cell line: 0>()
#       4 print("---------------------------------------------")
#       5
# ----> 6 import subprocess; subprocess.run([
#       7     "python", "src/helper/train.py",
#       8     "--data_dir", "./data/processed/ALT",
#
# /usr/lib/python3.11/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548     with Popen(*popenargs, **kwargs) as process:
#     549         try:
# --> 550             stdout, stderr = process.communicate(input, timeout=timeout)
#     551         except TimeoutExpired as exc:
#     552             process.kill()
#
# /usr/lib/python3.11/subprocess.py in communicate(self, input, timeout)
#    1199                 stderr = self.stderr.read()
#    1200                 self.stderr.close()
# -> 1201             self.wait()
#    1202         else:
#    1203             if timeout is not None:
#
# /usr/lib/python3.11/subprocess.py in wait(self, timeout)
#    1262             endtime = _time() + timeout
#    1263         try:
# -> 1264             return self._wait(timeout=timeout)
#    1265         except KeyboardInterrupt:
#    1266             # https://bugs.python.org/issue25942
#
# /usr/lib/python3.11/subprocess.py in _wait(self, timeout)
#    2051                         if self.returncode is not None:
#    2052                             break  # Another thread waited.
# -> 2053                         (pid, sts) = self._try_wait(0)
#    2054                         # Check the pid and loop as waitpid has been known to
#    2055                         # return 0 even without WNOHANG in odd situations.
#
# /usr/lib/python3.11/subprocess.py in _try_wait(self, wait_flags)
#    2009             """All callers to this function MUST hold self._waitpid_lock."""
#    2010             try:
# -> 2011                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    2012             except ChildProcessError:
#    2013                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:
